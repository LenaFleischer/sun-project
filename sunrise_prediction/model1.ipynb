# %% [markdown]
# ### Sunrise model
# based on a labeled weather dataset, predict whether the next sunrise will be beautiful
# - takes in weather vector for entire day for 365 days in COS AND label of good or bad

# %%
import torch
import os 
import numpy as np
import matplotlib.pyplot as plt

# dependencies: python 3.9, numpy 1.19.5

# %% [markdown]
# - load in weather data using only valid columns, leaving out the last column (wind chill label)
# - create a tensor from all data

# %%
input_path = "prepped_data_1.csv"
test_path = "test_data_1.csv"
weather_data = np.genfromtxt(input_path,delimiter = ",", skip_header = 1, filling_values=0.0)
weather_tensor = torch.tensor(weather_data).float()

SETTING = "sunrise"

# %% [markdown]
# read in as a tensor dataset

# %%
# get labels from the sunrise, sunset columns

sunrise_labels = weather_tensor[:, -2]
sunset_labels = weather_tensor[:, -1]
data = weather_tensor[:,:-2] # all weather data except sunrise and sunset labels

# %%
# TEST = the last 365 days worth
# TEST = 8760
# sunrise_labels = weather_tensor[-TEST:, -2]
# sunset_labels = weather_tensor[-TEST:, -1]
# data = weather_tensor[-TEST:,:-2] # all weather data except sunrise and sunset labels

# %% [markdown]
# # normalization

# %%
# calculate mean and std and do the normalization by hand 
m = torch.mean(data, dim = 0)
s = torch.std(data, dim = 0)

norm_data = (data - m)/s


m = m.detach().numpy().tolist()
s = s.detach().numpy().tolist()

# print(m)

import json

mean = json.dumps(m)
std = json.dumps(s)


with open('mean.json', 'w') as f:
    f.write(mean)
with open('std.json', 'w') as f:
    f.write(std)

# %%
weather_dataset = torch.utils.data.TensorDataset(norm_data, sunrise_labels)
# number of columns (minus the labels columns)
xdims = weather_tensor.shape[1] - 2
# number of rows 
ydims = weather_tensor.shape[0]


# test_sunrise_labels = weather_tensor[-TEST:, -2]
# test_sunset_labels = weather_tensor[-TEST:, -1]
# test_data = weather_tensor[-TEST:,:-2]

# %% [markdown]
# DataLoader
# puts data on the right device, shuffles, can use parallel programming, define batch size etc
# - sees everything in an epoch
# - next epoch, sees them in a different order
# - suffles with 32 irows in a batch

# %%
loader = torch.utils.data.DataLoader(weather_dataset, shuffle=True, batch_size=32)

# %%
net = torch.nn.Sequential(
    torch.nn.Linear(xdims, 32), # takes in x dims columns, then funnels to a hidden layer of 32
    torch.nn.ELU(), 
    # ELU is an activation layer, like a sigmoidal function!
    torch.nn.Linear(32, 32),
    torch.nn.ELU(),
    torch.nn.Linear(32, 16),
    torch.nn.ELU(),
    torch.nn.Linear(16, 1)
)

# %%
# Mean squared error loss function
# criterion = torch.nn.MSELoss()

## changing this to binary cross entropy with logits 
# w logits is more numerically stable 
criterion = torch.nn.BCEWithLogitsLoss()

# %%
# optimizer called Adam, using a learning rate of 1e-4
opt = torch.optim.Adam(net.parameters(), 1e-4 )

# %% [markdown]
# Training loop

# %%
for ep in range(1000):
    # every epoch sees every row exactly one time, but inputs are shuffled every epoch
    total_loss = 0.0

    # batch by batch
    for batch in loader:

        opt.zero_grad()

        batchX = batch[0]
        batchY = batch[1].unsqueeze(-1) # take this from size [21] --> size [21, 1]

        pred = net(batchX)
        loss = criterion(pred, batchY)

        loss.backward()
        opt.step()
        total_loss += loss
        
    if ep%30 == 0: 
        print("--- epoch " + str(ep))
        print(total_loss)
# Out:
# --- epoch 0
# tensor(1202.2461, grad_fn=<AddBackward0>)
# --- epoch 30
# tensor(1102.2493, grad_fn=<AddBackward0>)
# --- epoch 60
# tensor(1093.4526, grad_fn=<AddBackward0>)
# --- epoch 90
# tensor(1087.2734, grad_fn=<AddBackward0>)
# --- epoch 120
# tensor(1081.5724, grad_fn=<AddBackward0>)
# --- epoch 150
# tensor(1076.0769, grad_fn=<AddBackward0>)
# --- epoch 180
# tensor(1070.4724, grad_fn=<AddBackward0>)
# --- epoch 210
# tensor(1064.5874, grad_fn=<AddBackward0>)
# --- epoch 240
# tensor(1058.8632, grad_fn=<AddBackward0>)
# --- epoch 270
# tensor(1053.1102, grad_fn=<AddBackward0>)
# --- epoch 300
# tensor(1047.9794, grad_fn=<AddBackward0>)
# --- epoch 330
# tensor(1042.7988, grad_fn=<AddBackward0>)
# --- epoch 360
# tensor(1038.8032, grad_fn=<AddBackward0>)
# --- epoch 390
# tensor(1033.8427, grad_fn=<AddBackward0>)
# --- epoch 420
# tensor(1029.2599, grad_fn=<AddBackward0>)
# --- epoch 450
# tensor(1025.2666, grad_fn=<AddBackward0>)
# --- epoch 480
# tensor(1020.4306, grad_fn=<AddBackward0>)
# --- epoch 510
# tensor(1016.4425, grad_fn=<AddBackward0>)
# --- epoch 540
# tensor(1012.2601, grad_fn=<AddBackward0>)
# --- epoch 570
# tensor(1009.1852, grad_fn=<AddBackward0>)
# --- epoch 600
# tensor(1004.7143, grad_fn=<AddBackward0>)
# --- epoch 630
# tensor(1002.5214, grad_fn=<AddBackward0>)
# --- epoch 660
# tensor(998.5016, grad_fn=<AddBackward0>)
# --- epoch 690
# tensor(995.1301, grad_fn=<AddBackward0>)
# --- epoch 720
# tensor(992.3115, grad_fn=<AddBackward0>)
# --- epoch 750
# tensor(989.5084, grad_fn=<AddBackward0>)
# --- epoch 780
# tensor(985.7452, grad_fn=<AddBackward0>)
# --- epoch 810
# tensor(983.6840, grad_fn=<AddBackward0>)
# --- epoch 840
# tensor(980.4788, grad_fn=<AddBackward0>)
# --- epoch 870
# tensor(978.0688, grad_fn=<AddBackward0>)
# --- epoch 900
# tensor(975.2681, grad_fn=<AddBackward0>)
# --- epoch 930
# tensor(972.6002, grad_fn=<AddBackward0>)
# --- epoch 960
# tensor(970.0992, grad_fn=<AddBackward0>)
# --- epoch 990
# tensor(967.4196, grad_fn=<AddBackward0>)

# %% [markdown]
# ### Test data

# %%
test_data = np.genfromtxt(input_path,delimiter = ",", skip_header = 1, filling_values=0.0)
test_tensor = torch.tensor(test_data).float()
test_data = test_tensor[:,:-2]

# sunrise
test_labels = test_tensor[:,-2] 

# sunset
#test_labels = test_tensor[:,-1]

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn import metrics

actual = np.asarray(test_labels)

# normalize test_data using previously defined mean and std
m = torch.mean(data, dim = 0)
s = torch.std(data, dim = 0)
test_data = (test_data - m)/s

predicted = []
# predicted is the sigmoid of the output from the net
for i, vector in enumerate(test_data): 
    prediction = torch.sigmoid(net(vector))
    predicted.append(prediction)
    
print(predicted[:100])
predicted = [1.0 if (x >.5) else 0.0 for x in predicted ]
predicted = np.asarray(predicted)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()
# Out:
# [tensor([0.6912], grad_fn=<SigmoidBackward0>), tensor([0.6755], grad_fn=<SigmoidBackward0>), tensor([0.7496], grad_fn=<SigmoidBackward0>), tensor([0.6784], grad_fn=<SigmoidBackward0>), tensor([0.6614], grad_fn=<SigmoidBackward0>), tensor([0.7237], grad_fn=<SigmoidBackward0>), tensor([0.6582], grad_fn=<SigmoidBackward0>), tensor([0.3122], grad_fn=<SigmoidBackward0>), tensor([0.2026], grad_fn=<SigmoidBackward0>), tensor([0.2141], grad_fn=<SigmoidBackward0>), tensor([0.4772], grad_fn=<SigmoidBackward0>), tensor([0.1661], grad_fn=<SigmoidBackward0>), tensor([0.1395], grad_fn=<SigmoidBackward0>), tensor([0.2065], grad_fn=<SigmoidBackward0>), tensor([0.2212], grad_fn=<SigmoidBackward0>), tensor([0.4660], grad_fn=<SigmoidBackward0>), tensor([0.4775], grad_fn=<SigmoidBackward0>), tensor([0.4479], grad_fn=<SigmoidBackward0>), tensor([0.3034], grad_fn=<SigmoidBackward0>), tensor([0.1737], grad_fn=<SigmoidBackward0>), tensor([0.1437], grad_fn=<SigmoidBackward0>), tensor([0.1483], grad_fn=<SigmoidBackward0>), tensor([0.2077], grad_fn=<SigmoidBackward0>), tensor([0.0197], grad_fn=<SigmoidBackward0>), tensor([0.5636], grad_fn=<SigmoidBackward0>), tensor([0.1219], grad_fn=<SigmoidBackward0>), tensor([0.1651], grad_fn=<SigmoidBackward0>), tensor([0.1327], grad_fn=<SigmoidBackward0>), tensor([0.1467], grad_fn=<SigmoidBackward0>), tensor([0.1529], grad_fn=<SigmoidBackward0>), tensor([0.1352], grad_fn=<SigmoidBackward0>), tensor([0.4874], grad_fn=<SigmoidBackward0>), tensor([0.1255], grad_fn=<SigmoidBackward0>), tensor([0.1643], grad_fn=<SigmoidBackward0>), tensor([0.3971], grad_fn=<SigmoidBackward0>), tensor([0.3019], grad_fn=<SigmoidBackward0>), tensor([0.1950], grad_fn=<SigmoidBackward0>), tensor([0.0495], grad_fn=<SigmoidBackward0>), tensor([0.0916], grad_fn=<SigmoidBackward0>), tensor([0.1695], grad_fn=<SigmoidBackward0>), tensor([0.1437], grad_fn=<SigmoidBackward0>), tensor([0.2615], grad_fn=<SigmoidBackward0>), tensor([0.5168], grad_fn=<SigmoidBackward0>), tensor([0.5817], grad_fn=<SigmoidBackward0>), tensor([0.0861], grad_fn=<SigmoidBackward0>), tensor([0.1145], grad_fn=<SigmoidBackward0>), tensor([0.0673], grad_fn=<SigmoidBackward0>), tensor([0.0688], grad_fn=<SigmoidBackward0>), tensor([0.1022], grad_fn=<SigmoidBackward0>), tensor([0.6912], grad_fn=<SigmoidBackward0>), tensor([0.1048], grad_fn=<SigmoidBackward0>), tensor([0.4406], grad_fn=<SigmoidBackward0>), tensor([0.5842], grad_fn=<SigmoidBackward0>), tensor([0.1824], grad_fn=<SigmoidBackward0>), tensor([0.5954], grad_fn=<SigmoidBackward0>), tensor([0.6039], grad_fn=<SigmoidBackward0>), tensor([0.6516], grad_fn=<SigmoidBackward0>), tensor([0.6637], grad_fn=<SigmoidBackward0>), tensor([0.3243], grad_fn=<SigmoidBackward0>), tensor([0.0628], grad_fn=<SigmoidBackward0>), tensor([0.4424], grad_fn=<SigmoidBackward0>), tensor([0.7047], grad_fn=<SigmoidBackward0>), tensor([0.5918], grad_fn=<SigmoidBackward0>), tensor([0.7075], grad_fn=<SigmoidBackward0>), tensor([0.5013], grad_fn=<SigmoidBackward0>), tensor([0.6176], grad_fn=<SigmoidBackward0>), tensor([0.7617], grad_fn=<SigmoidBackward0>), tensor([0.5816], grad_fn=<SigmoidBackward0>), tensor([0.3037], grad_fn=<SigmoidBackward0>), tensor([0.1814], grad_fn=<SigmoidBackward0>), tensor([0.1207], grad_fn=<SigmoidBackward0>), tensor([0.0906], grad_fn=<SigmoidBackward0>), tensor([0.1297], grad_fn=<SigmoidBackward0>), tensor([0.1228], grad_fn=<SigmoidBackward0>), tensor([0.1219], grad_fn=<SigmoidBackward0>), tensor([0.3942], grad_fn=<SigmoidBackward0>), tensor([0.3725], grad_fn=<SigmoidBackward0>), tensor([0.3840], grad_fn=<SigmoidBackward0>), tensor([0.4629], grad_fn=<SigmoidBackward0>), tensor([0.3328], grad_fn=<SigmoidBackward0>), tensor([0.1985], grad_fn=<SigmoidBackward0>), tensor([0.2633], grad_fn=<SigmoidBackward0>), tensor([0.2339], grad_fn=<SigmoidBackward0>), tensor([0.1888], grad_fn=<SigmoidBackward0>), tensor([0.1023], grad_fn=<SigmoidBackward0>), tensor([0.0853], grad_fn=<SigmoidBackward0>), tensor([0.0882], grad_fn=<SigmoidBackward0> ...

# %% [markdown]
# ### Test

# %%
# input_path = "prepped_data_1.csv"
# test_data = np.genfromtxt(input_path,delimiter = ",", skip_header = 1, filling_values=0.0)
# test_tensor = torch.tensor(test_data).float()

# # test_sunrise_labels = weather_tensor[-TEST:, -2]
# # # test_sunset_labels = weather_tensor[-TEST:, -1]
# # test_data = weather_tensor[-TEST:,:-2] 



# for i, vector in enumerate(test_data): 
#     prediction = net(vector)
#     real = test_sunrise_labels[i]
#     print(prediction)
# Out:
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.2973], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.3009], grad_fn=<AddBackward0>)
# tensor([0.3005], grad_fn=<AddBackward0>)
# tensor([0.2902], grad_fn=<AddBackward0>)
# tensor([0.3002], grad_fn=<AddBackward0>)
# tensor([0.3016], grad_fn=<AddBackward0>)
# tensor([0.3066], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2957], grad_fn=<AddBackward0>)
# tensor([0.2839], grad_fn=<AddBackward0>)
# tensor([0.2829], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2885], grad_fn=<AddBackward0>)
# tensor([0.2826], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2883], grad_fn=<AddBackward0>)
# tensor([0.2891], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2920], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2887], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2882], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2907], grad_fn=<AddBackward0>)
# tensor([0.2886], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2974], grad_fn=<AddBackward0>)
# tensor([0.2987], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2884], grad_fn=<AddBackward0>)
# tensor([0.2772], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2907], grad_fn=<AddBackward0>)
# tensor([0.2930], grad_fn=<AddBackward0>)
# tensor([0.2915], grad_fn=<AddBackward0>)
# tensor([0.2907], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2831], grad_fn=<AddBackward0>)
# tensor([0.2837], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2950], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2869], grad_fn=<AddBackward0>)
# tensor([0.2878], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2866], grad_fn=<AddBackward0>)
# tensor([0.2864], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2804], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2817], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2935], grad_fn=<AddBackward0>)
# tensor([0.2927], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2884], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2812], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2869], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2882], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2806], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2839], grad_fn=<AddBackward0>)
# tensor([0.2893], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2864], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2801], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2882], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2790], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2816], grad_fn=<AddBackward0>)
# tensor([0.2837], grad_fn=<AddBackward0>)
# tensor([0.2854], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2882], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2818], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2837], grad_fn=<AddBackward0>)
# tensor([0.2809], grad_fn=<AddBackward0>)
# tensor([0.2831], grad_fn=<AddBackward0>)
# tensor([0.2802], grad_fn=<AddBackward0>)
# tensor([0.2805], grad_fn=<AddBackward0>)
# tensor([0.2817], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2908], grad_fn=<AddBackward0>)
# tensor([0.2934], grad_fn=<AddBackward0>)
# tensor([0.2999], grad_fn=<AddBackward0>)
# tensor([0.2904], grad_fn=<AddBackward0>)
# tensor([0.2953], grad_fn=<AddBackward0>)
# tensor([0.2958], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2932], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.2950], grad_fn=<AddBackward0>)
# tensor([0.2955], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2972], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2940], grad_fn=<AddBackward0>)
# tensor([0.2956], grad_fn=<AddBackward0>)
# tensor([0.2961], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2859], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2831], grad_fn=<AddBackward0>)
# tensor([0.2801], grad_fn=<AddBackward0>)
# tensor([0.2923], grad_fn=<AddBackward0>)
# tensor([0.2981], grad_fn=<AddBackward0>)
# tensor([0.3001], grad_fn=<AddBackward0>)
# tensor([0.2969], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2984], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2935], grad_fn=<AddBackward0>)
# tensor([0.2946], grad_fn=<AddBackward0>)
# tensor([0.2979], grad_fn=<AddBackward0>)
# tensor([0.3007], grad_fn=<AddBackward0>)
# tensor([0.2986], grad_fn=<AddBackward0>)
# tensor([0.2962], grad_fn=<AddBackward0>)
# tensor([0.2971], grad_fn=<AddBackward0>)
# tensor([0.3011], grad_fn=<AddBackward0>)
# tensor([0.3002], grad_fn=<AddBackward0>)
# tensor([0.2994], grad_fn=<AddBackward0>)
# tensor([0.3038], grad_fn=<AddBackward0>)
# tensor([0.2920], grad_fn=<AddBackward0>)
# tensor([0.2968], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2955], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2888], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2837], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2893], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2854], grad_fn=<AddBackward0>)
# tensor([0.2886], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2864], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2880], grad_fn=<AddBackward0>)
# tensor([0.2892], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.2878], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2915], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2923], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2862], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2834], grad_fn=<AddBackward0>)
# tensor([0.2818], grad_fn=<AddBackward0>)
# tensor([0.2821], grad_fn=<AddBackward0>)
# tensor([0.2812], grad_fn=<AddBackward0>)
# tensor([0.2808], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2820], grad_fn=<AddBackward0>)
# tensor([0.2812], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2835], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2814], grad_fn=<AddBackward0>)
# tensor([0.2808], grad_fn=<AddBackward0>)
# tensor([0.2822], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2888], grad_fn=<AddBackward0>)
# tensor([0.2926], grad_fn=<AddBackward0>)
# tensor([0.2891], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2904], grad_fn=<AddBackward0>)
# tensor([0.2908], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2855], grad_fn=<AddBackward0>)
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.2891], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2823], grad_fn=<AddBackward0>)
# tensor([0.2866], grad_fn=<AddBackward0>)
# tensor([0.2896], grad_fn=<AddBackward0>)
# tensor([0.2887], grad_fn=<AddBackward0>)
# tensor([0.2929], grad_fn=<AddBackward0>)
# tensor([0.2940], grad_fn=<AddBackward0>)
# tensor([0.2924], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2825], grad_fn=<AddBackward0>)
# tensor([0.2809], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2825], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2855], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2880], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2918], grad_fn=<AddBackward0>)
# tensor([0.2906], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2819], grad_fn=<AddBackward0>)
# tensor([0.2818], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2825], grad_fn=<AddBackward0>)
# tensor([0.2793], grad_fn=<AddBackward0>)
# tensor([0.2809], grad_fn=<AddBackward0>)
# tensor([0.2772], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2988], grad_fn=<AddBackward0>)
# tensor([0.2926], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2834], grad_fn=<AddBackward0>)
# tensor([0.2835], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2816], grad_fn=<AddBackward0>)
# tensor([0.2811], grad_fn=<AddBackward0>)
# tensor([0.2839], grad_fn=<AddBackward0>)
# tensor([0.2880], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2823], grad_fn=<AddBackward0>)
# tensor([0.2826], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2831], grad_fn=<AddBackward0>)
# tensor([0.2854], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2828], grad_fn=<AddBackward0>)
# tensor([0.2773], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2805], grad_fn=<AddBackward0>)
# tensor([0.2823], grad_fn=<AddBackward0>)
# tensor([0.2817], grad_fn=<AddBackward0>)
# tensor([0.2812], grad_fn=<AddBackward0>)
# tensor([0.2812], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2831], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2837], grad_fn=<AddBackward0>)
# tensor([0.2839], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2830], grad_fn=<AddBackward0>)
# tensor([0.2817], grad_fn=<AddBackward0>)
# tensor([0.2816], grad_fn=<AddBackward0>)
# tensor([0.2837], grad_fn=<AddBackward0>)
# tensor([0.2796], grad_fn=<AddBackward0>)
# tensor([0.2790], grad_fn=<AddBackward0>)
# tensor([0.2786], grad_fn=<AddBackward0>)
# tensor([0.2786], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2784], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2932], grad_fn=<AddBackward0>)
# tensor([0.2915], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2908], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2806], grad_fn=<AddBackward0>)
# tensor([0.2988], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2893], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2869], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2823], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2834], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2825], grad_fn=<AddBackward0>)
# tensor([0.2826], grad_fn=<AddBackward0>)
# tensor([0.2855], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2829], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2831], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2834], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2825], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2805], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.3065], grad_fn=<AddBackward0>)
# tensor([0.3061], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.3026], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.3010], grad_fn=<AddBackward0>)
# tensor([0.3009], grad_fn=<AddBackward0>)
# tensor([0.3015], grad_fn=<AddBackward0>)
# tensor([0.2923], grad_fn=<AddBackward0>)
# tensor([0.3011], grad_fn=<AddBackward0>)
# tensor([0.3025], grad_fn=<AddBackward0>)
# tensor([0.3023], grad_fn=<AddBackward0>)
# tensor([0.3053], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2975], grad_fn=<AddBackward0>)
# tensor([0.2976], grad_fn=<AddBackward0>)
# tensor([0.2950], grad_fn=<AddBackward0>)
# tensor([0.2983], grad_fn=<AddBackward0>)
# tensor([0.2946], grad_fn=<AddBackward0>)
# tensor([0.2907], grad_fn=<AddBackward0>)
# tensor([0.2887], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2940], grad_fn=<AddBackward0>)
# tensor([0.2926], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2925], grad_fn=<AddBackward0>)
# tensor([0.2878], grad_fn=<AddBackward0>)
# tensor([0.2918], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2877], grad_fn=<AddBackward0>)
# tensor([0.2956], grad_fn=<AddBackward0>)
# tensor([0.2965], grad_fn=<AddBackward0>)
# tensor([0.3026], grad_fn=<AddBackward0>)
# tensor([0.2993], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.2922], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.2935], grad_fn=<AddBackward0>)
# tensor([0.2957], grad_fn=<AddBackward0>)
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.3011], grad_fn=<AddBackward0>)
# tensor([0.3061], grad_fn=<AddBackward0>)
# tensor([0.3037], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.2955], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.3065], grad_fn=<AddBackward0>)
# tensor([0.2943], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2955], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2935], grad_fn=<AddBackward0>)
# tensor([0.2968], grad_fn=<AddBackward0>)
# tensor([0.2997], grad_fn=<AddBackward0>)
# tensor([0.2868], grad_fn=<AddBackward0>)
# tensor([0.2997], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2919], grad_fn=<AddBackward0>)
# tensor([0.3036], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2973], grad_fn=<AddBackward0>)
# tensor([0.2979], grad_fn=<AddBackward0>)
# tensor([0.2974], grad_fn=<AddBackward0>)
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.2963], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2944], grad_fn=<AddBackward0>)
# tensor([0.2906], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2940], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2741], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2806], grad_fn=<AddBackward0>)
# tensor([0.2804], grad_fn=<AddBackward0>)
# tensor([0.2814], grad_fn=<AddBackward0>)
# tensor([0.2816], grad_fn=<AddBackward0>)
# tensor([0.2761], grad_fn=<AddBackward0>)
# tensor([0.2838], grad_fn=<AddBackward0>)
# tensor([0.2880], grad_fn=<AddBackward0>)
# tensor([0.2922], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.2893], grad_fn=<AddBackward0>)
# tensor([0.2909], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2885], grad_fn=<AddBackward0>)
# tensor([0.2880], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2859], grad_fn=<AddBackward0>)
# tensor([0.2943], grad_fn=<AddBackward0>)
# tensor([0.2866], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2854], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2764], grad_fn=<AddBackward0>)
# tensor([0.2747], grad_fn=<AddBackward0>)
# tensor([0.2821], grad_fn=<AddBackward0>)
# tensor([0.2732], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2753], grad_fn=<AddBackward0>)
# tensor([0.2683], grad_fn=<AddBackward0>)
# tensor([0.2767], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2839], grad_fn=<AddBackward0>)
# tensor([0.2834], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2975], grad_fn=<AddBackward0>)
# tensor([0.2979], grad_fn=<AddBackward0>)
# tensor([0.2957], grad_fn=<AddBackward0>)
# tensor([0.3001], grad_fn=<AddBackward0>)
# tensor([0.2964], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2966], grad_fn=<AddBackward0>)
# tensor([0.2929], grad_fn=<AddBackward0>)
# tensor([0.2967], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2885], grad_fn=<AddBackward0>)
# tensor([0.2882], grad_fn=<AddBackward0>)
# tensor([0.2892], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2892], grad_fn=<AddBackward0>)
# tensor([0.2931], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2875], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2875], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2855], grad_fn=<AddBackward0>)
# tensor([0.2866], grad_fn=<AddBackward0>)
# tensor([0.3011], grad_fn=<AddBackward0>)
# tensor([0.3006], grad_fn=<AddBackward0>)
# tensor([0.2956], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2965], grad_fn=<AddBackward0>)
# tensor([0.2953], grad_fn=<AddBackward0>)
# tensor([0.2961], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.2995], grad_fn=<AddBackward0>)
# tensor([0.2995], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2975], grad_fn=<AddBackward0>)
# tensor([0.2973], grad_fn=<AddBackward0>)
# tensor([0.2963], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2983], grad_fn=<AddBackward0>)
# tensor([0.3006], grad_fn=<AddBackward0>)
# tensor([0.3032], grad_fn=<AddBackward0>)
# tensor([0.3033], grad_fn=<AddBackward0>)
# tensor([0.3030], grad_fn=<AddBackward0>)
# tensor([0.2994], grad_fn=<AddBackward0>)
# tensor([0.2975], grad_fn=<AddBackward0>)
# tensor([0.3013], grad_fn=<AddBackward0>)
# tensor([0.3045], grad_fn=<AddBackward0>)
# tensor([0.3028], grad_fn=<AddBackward0>)
# tensor([0.3026], grad_fn=<AddBackward0>)
# tensor([0.3025], grad_fn=<AddBackward0>)
# tensor([0.2999], grad_fn=<AddBackward0>)
# tensor([0.3017], grad_fn=<AddBackward0>)
# tensor([0.3016], grad_fn=<AddBackward0>)
# tensor([0.2992], grad_fn=<AddBackward0>)
# tensor([0.2987], grad_fn=<AddBackward0>)
# tensor([0.2982], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2974], grad_fn=<AddBackward0>)
# tensor([0.2983], grad_fn=<AddBackward0>)
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2932], grad_fn=<AddBackward0>)
# tensor([0.2934], grad_fn=<AddBackward0>)
# tensor([0.2973], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2998], grad_fn=<AddBackward0>)
# tensor([0.3000], grad_fn=<AddBackward0>)
# tensor([0.3011], grad_fn=<AddBackward0>)
# tensor([0.3011], grad_fn=<AddBackward0>)
# tensor([0.3014], grad_fn=<AddBackward0>)
# tensor([0.2971], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2981], grad_fn=<AddBackward0>)
# tensor([0.2960], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2944], grad_fn=<AddBackward0>)
# tensor([0.2969], grad_fn=<AddBackward0>)
# tensor([0.3009], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.3006], grad_fn=<AddBackward0>)
# tensor([0.2980], grad_fn=<AddBackward0>)
# tensor([0.2985], grad_fn=<AddBackward0>)
# tensor([0.2994], grad_fn=<AddBackward0>)
# tensor([0.2976], grad_fn=<AddBackward0>)
# tensor([0.2949], grad_fn=<AddBackward0>)
# tensor([0.2922], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2990], grad_fn=<AddBackward0>)
# tensor([0.3002], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.3067], grad_fn=<AddBackward0>)
# tensor([0.3050], grad_fn=<AddBackward0>)
# tensor([0.3036], grad_fn=<AddBackward0>)
# tensor([0.3013], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2945], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2817], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2908], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2953], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2918], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2932], grad_fn=<AddBackward0>)
# tensor([0.2987], grad_fn=<AddBackward0>)
# tensor([0.2915], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.2969], grad_fn=<AddBackward0>)
# tensor([0.2971], grad_fn=<AddBackward0>)
# tensor([0.3002], grad_fn=<AddBackward0>)
# tensor([0.2920], grad_fn=<AddBackward0>)
# tensor([0.3014], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2885], grad_fn=<AddBackward0>)
# tensor([0.2882], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2877], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2829], grad_fn=<AddBackward0>)
# tensor([0.2835], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2885], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2906], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2880], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2888], grad_fn=<AddBackward0>)
# tensor([0.2878], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2943], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2839], grad_fn=<AddBackward0>)
# tensor([0.2837], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2839], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2887], grad_fn=<AddBackward0>)
# tensor([0.2907], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2891], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2894], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2819], grad_fn=<AddBackward0>)
# tensor([0.2810], grad_fn=<AddBackward0>)
# tensor([0.2838], grad_fn=<AddBackward0>)
# tensor([0.2822], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.3030], grad_fn=<AddBackward0>)
# tensor([0.3030], grad_fn=<AddBackward0>)
# tensor([0.3034], grad_fn=<AddBackward0>)
# tensor([0.2969], grad_fn=<AddBackward0>)
# tensor([0.3007], grad_fn=<AddBackward0>)
# tensor([0.3045], grad_fn=<AddBackward0>)
# tensor([0.3010], grad_fn=<AddBackward0>)
# tensor([0.2958], grad_fn=<AddBackward0>)
# tensor([0.3026], grad_fn=<AddBackward0>)
# tensor([0.3016], grad_fn=<AddBackward0>)
# tensor([0.2993], grad_fn=<AddBackward0>)
# tensor([0.2914], grad_fn=<AddBackward0>)
# tensor([0.2971], grad_fn=<AddBackward0>)
# tensor([0.3012], grad_fn=<AddBackward0>)
# tensor([0.3005], grad_fn=<AddBackward0>)
# tensor([0.2944], grad_fn=<AddBackward0>)
# tensor([0.2888], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2855], grad_fn=<AddBackward0>)
# tensor([0.3007], grad_fn=<AddBackward0>)
# tensor([0.3040], grad_fn=<AddBackward0>)
# tensor([0.3035], grad_fn=<AddBackward0>)
# tensor([0.2972], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2806], grad_fn=<AddBackward0>)
# tensor([0.2797], grad_fn=<AddBackward0>)
# tensor([0.2807], grad_fn=<AddBackward0>)
# tensor([0.2813], grad_fn=<AddBackward0>)
# tensor([0.2805], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2796], grad_fn=<AddBackward0>)
# tensor([0.2870], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2975], grad_fn=<AddBackward0>)
# tensor([0.2997], grad_fn=<AddBackward0>)
# tensor([0.3013], grad_fn=<AddBackward0>)
# tensor([0.2939], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2972], grad_fn=<AddBackward0>)
# tensor([0.2961], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2997], grad_fn=<AddBackward0>)
# tensor([0.2987], grad_fn=<AddBackward0>)
# tensor([0.3029], grad_fn=<AddBackward0>)
# tensor([0.3042], grad_fn=<AddBackward0>)
# tensor([0.2974], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.3030], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2838], grad_fn=<AddBackward0>)
# tensor([0.2829], grad_fn=<AddBackward0>)
# tensor([0.2823], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2763], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2826], grad_fn=<AddBackward0>)
# tensor([0.2859], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2825], grad_fn=<AddBackward0>)
# tensor([0.2767], grad_fn=<AddBackward0>)
# tensor([0.2820], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2784], grad_fn=<AddBackward0>)
# tensor([0.2806], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.3030], grad_fn=<AddBackward0>)
# tensor([0.3057], grad_fn=<AddBackward0>)
# tensor([0.2915], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2831], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2896], grad_fn=<AddBackward0>)
# tensor([0.2907], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2966], grad_fn=<AddBackward0>)
# tensor([0.2966], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2914], grad_fn=<AddBackward0>)
# tensor([0.2933], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2963], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2904], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2894], grad_fn=<AddBackward0>)
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.2957], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2838], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2900], grad_fn=<AddBackward0>)
# tensor([0.3017], grad_fn=<AddBackward0>)
# tensor([0.2934], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.2830], grad_fn=<AddBackward0>)
# tensor([0.2829], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2823], grad_fn=<AddBackward0>)
# tensor([0.2825], grad_fn=<AddBackward0>)
# tensor([0.2787], grad_fn=<AddBackward0>)
# tensor([0.2927], grad_fn=<AddBackward0>)
# tensor([0.3007], grad_fn=<AddBackward0>)
# tensor([0.2906], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2944], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2892], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2886], grad_fn=<AddBackward0>)
# tensor([0.2907], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2886], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2941], grad_fn=<AddBackward0>)
# tensor([0.2943], grad_fn=<AddBackward0>)
# tensor([0.2941], grad_fn=<AddBackward0>)
# tensor([0.2951], grad_fn=<AddBackward0>)
# tensor([0.2900], grad_fn=<AddBackward0>)
# tensor([0.2906], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2896], grad_fn=<AddBackward0>)
# tensor([0.2878], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2883], grad_fn=<AddBackward0>)
# tensor([0.2884], grad_fn=<AddBackward0>)
# tensor([0.2887], grad_fn=<AddBackward0>)
# tensor([0.2891], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2894], grad_fn=<AddBackward0>)
# tensor([0.3007], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2993], grad_fn=<AddBackward0>)
# tensor([0.2998], grad_fn=<AddBackward0>)
# tensor([0.2996], grad_fn=<AddBackward0>)
# tensor([0.2855], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2909], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2915], grad_fn=<AddBackward0>)
# tensor([0.2918], grad_fn=<AddBackward0>)
# tensor([0.2926], grad_fn=<AddBackward0>)
# tensor([0.2924], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.3028], grad_fn=<AddBackward0>)
# tensor([0.2998], grad_fn=<AddBackward0>)
# tensor([0.2939], grad_fn=<AddBackward0>)
# tensor([0.2935], grad_fn=<AddBackward0>)
# tensor([0.2972], grad_fn=<AddBackward0>)
# tensor([0.2892], grad_fn=<AddBackward0>)
# tensor([0.2962], grad_fn=<AddBackward0>)
# tensor([0.2880], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2972], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2939], grad_fn=<AddBackward0>)
# tensor([0.2952], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2970], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2883], grad_fn=<AddBackward0>)
# tensor([0.2976], grad_fn=<AddBackward0>)
# tensor([0.3062], grad_fn=<AddBackward0>)
# tensor([0.3090], grad_fn=<AddBackward0>)
# tensor([0.2991], grad_fn=<AddBackward0>)
# tensor([0.2983], grad_fn=<AddBackward0>)
# tensor([0.2994], grad_fn=<AddBackward0>)
# tensor([0.3018], grad_fn=<AddBackward0>)
# tensor([0.3018], grad_fn=<AddBackward0>)
# tensor([0.2994], grad_fn=<AddBackward0>)
# tensor([0.2926], grad_fn=<AddBackward0>)
# tensor([0.2953], grad_fn=<AddBackward0>)
# tensor([0.3007], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2870], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2868], grad_fn=<AddBackward0>)
# tensor([0.2866], grad_fn=<AddBackward0>)
# tensor([0.2869], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2833], grad_fn=<AddBackward0>)
# tensor([0.2864], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2838], grad_fn=<AddBackward0>)
# tensor([0.2824], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2775], grad_fn=<AddBackward0>)
# tensor([0.2794], grad_fn=<AddBackward0>)
# tensor([0.2893], grad_fn=<AddBackward0>)
# tensor([0.2830], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2839], grad_fn=<AddBackward0>)
# tensor([0.2962], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2884], grad_fn=<AddBackward0>)
# tensor([0.2919], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2883], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2925], grad_fn=<AddBackward0>)
# tensor([0.3008], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2819], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2884], grad_fn=<AddBackward0>)
# tensor([0.2829], grad_fn=<AddBackward0>)
# tensor([0.2883], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2908], grad_fn=<AddBackward0>)
# tensor([0.2909], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2828], grad_fn=<AddBackward0>)
# tensor([0.2811], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2816], grad_fn=<AddBackward0>)
# tensor([0.2830], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2891], grad_fn=<AddBackward0>)
# tensor([0.2884], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2929], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2877], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2859], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2838], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2815], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2870], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2962], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2854], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2870], grad_fn=<AddBackward0>)
# tensor([0.2870], grad_fn=<AddBackward0>)
# tensor([0.2868], grad_fn=<AddBackward0>)
# tensor([0.2828], grad_fn=<AddBackward0>)
# tensor([0.2962], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2985], grad_fn=<AddBackward0>)
# tensor([0.2892], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2869], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2866], grad_fn=<AddBackward0>)
# tensor([0.2939], grad_fn=<AddBackward0>)
# tensor([0.2920], grad_fn=<AddBackward0>)
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2894], grad_fn=<AddBackward0>)
# tensor([0.2894], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.3026], grad_fn=<AddBackward0>)
# tensor([0.2990], grad_fn=<AddBackward0>)
# tensor([0.2994], grad_fn=<AddBackward0>)
# tensor([0.3003], grad_fn=<AddBackward0>)
# tensor([0.3031], grad_fn=<AddBackward0>)
# tensor([0.3032], grad_fn=<AddBackward0>)
# tensor([0.3039], grad_fn=<AddBackward0>)
# tensor([0.3064], grad_fn=<AddBackward0>)
# tensor([0.3028], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.3061], grad_fn=<AddBackward0>)
# tensor([0.3079], grad_fn=<AddBackward0>)
# tensor([0.3108], grad_fn=<AddBackward0>)
# tensor([0.3079], grad_fn=<AddBackward0>)
# tensor([0.3056], grad_fn=<AddBackward0>)
# tensor([0.2967], grad_fn=<AddBackward0>)
# tensor([0.3049], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.3123], grad_fn=<AddBackward0>)
# tensor([0.3025], grad_fn=<AddBackward0>)
# tensor([0.3016], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.2919], grad_fn=<AddBackward0>)
# tensor([0.3013], grad_fn=<AddBackward0>)
# tensor([0.2962], grad_fn=<AddBackward0>)
# tensor([0.3020], grad_fn=<AddBackward0>)
# tensor([0.2997], grad_fn=<AddBackward0>)
# tensor([0.3009], grad_fn=<AddBackward0>)
# tensor([0.3031], grad_fn=<AddBackward0>)
# tensor([0.3054], grad_fn=<AddBackward0>)
# tensor([0.3051], grad_fn=<AddBackward0>)
# tensor([0.3029], grad_fn=<AddBackward0>)
# tensor([0.2991], grad_fn=<AddBackward0>)
# tensor([0.3009], grad_fn=<AddBackward0>)
# tensor([0.3005], grad_fn=<AddBackward0>)
# tensor([0.2983], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2963], grad_fn=<AddBackward0>)
# tensor([0.2967], grad_fn=<AddBackward0>)
# tensor([0.2960], grad_fn=<AddBackward0>)
# tensor([0.2972], grad_fn=<AddBackward0>)
# tensor([0.3082], grad_fn=<AddBackward0>)
# tensor([0.3122], grad_fn=<AddBackward0>)
# tensor([0.3026], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2949], grad_fn=<AddBackward0>)
# tensor([0.2974], grad_fn=<AddBackward0>)
# tensor([0.3012], grad_fn=<AddBackward0>)
# tensor([0.2996], grad_fn=<AddBackward0>)
# tensor([0.3025], grad_fn=<AddBackward0>)
# tensor([0.3041], grad_fn=<AddBackward0>)
# tensor([0.2989], grad_fn=<AddBackward0>)
# tensor([0.2987], grad_fn=<AddBackward0>)
# tensor([0.2946], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2927], grad_fn=<AddBackward0>)
# tensor([0.2909], grad_fn=<AddBackward0>)
# tensor([0.2904], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2999], grad_fn=<AddBackward0>)
# tensor([0.3018], grad_fn=<AddBackward0>)
# tensor([0.2997], grad_fn=<AddBackward0>)
# tensor([0.2961], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.3143], grad_fn=<AddBackward0>)
# tensor([0.3019], grad_fn=<AddBackward0>)
# tensor([0.2919], grad_fn=<AddBackward0>)
# tensor([0.3075], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.2995], grad_fn=<AddBackward0>)
# tensor([0.3032], grad_fn=<AddBackward0>)
# tensor([0.3009], grad_fn=<AddBackward0>)
# tensor([0.3025], grad_fn=<AddBackward0>)
# tensor([0.3020], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2817], grad_fn=<AddBackward0>)
# tensor([0.2811], grad_fn=<AddBackward0>)
# tensor([0.2815], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2834], grad_fn=<AddBackward0>)
# tensor([0.2922], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2886], grad_fn=<AddBackward0>)
# tensor([0.3041], grad_fn=<AddBackward0>)
# tensor([0.3010], grad_fn=<AddBackward0>)
# tensor([0.2994], grad_fn=<AddBackward0>)
# tensor([0.2995], grad_fn=<AddBackward0>)
# tensor([0.3014], grad_fn=<AddBackward0>)
# tensor([0.2999], grad_fn=<AddBackward0>)
# tensor([0.3019], grad_fn=<AddBackward0>)
# tensor([0.2995], grad_fn=<AddBackward0>)
# tensor([0.2946], grad_fn=<AddBackward0>)
# tensor([0.3095], grad_fn=<AddBackward0>)
# tensor([0.2878], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2868], grad_fn=<AddBackward0>)
# tensor([0.2882], grad_fn=<AddBackward0>)
# tensor([0.2972], grad_fn=<AddBackward0>)
# tensor([0.3035], grad_fn=<AddBackward0>)
# tensor([0.3021], grad_fn=<AddBackward0>)
# tensor([0.3056], grad_fn=<AddBackward0>)
# tensor([0.3112], grad_fn=<AddBackward0>)
# tensor([0.2933], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2905], grad_fn=<AddBackward0>)
# tensor([0.3067], grad_fn=<AddBackward0>)
# tensor([0.2985], grad_fn=<AddBackward0>)
# tensor([0.2966], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2969], grad_fn=<AddBackward0>)
# tensor([0.2968], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2923], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2904], grad_fn=<AddBackward0>)
# tensor([0.2915], grad_fn=<AddBackward0>)
# ...
# tensor([0.2920], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2908], grad_fn=<AddBackward0>)
# tensor([0.2919], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2887], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2923], grad_fn=<AddBackward0>)
# tensor([0.2929], grad_fn=<AddBackward0>)
# tensor([0.2935], grad_fn=<AddBackward0>)
# tensor([0.2951], grad_fn=<AddBackward0>)
# tensor([0.2935], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2940], grad_fn=<AddBackward0>)
# tensor([0.2941], grad_fn=<AddBackward0>)
# tensor([0.2939], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2930], grad_fn=<AddBackward0>)
# tensor([0.2931], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2941], grad_fn=<AddBackward0>)
# tensor([0.2950], grad_fn=<AddBackward0>)
# tensor([0.2930], grad_fn=<AddBackward0>)
# tensor([0.2923], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2914], grad_fn=<AddBackward0>)
# tensor([0.2934], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2893], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2920], grad_fn=<AddBackward0>)
# tensor([0.2912], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2952], grad_fn=<AddBackward0>)
# tensor([0.2919], grad_fn=<AddBackward0>)
# tensor([0.2932], grad_fn=<AddBackward0>)
# tensor([0.2870], grad_fn=<AddBackward0>)
# tensor([0.2909], grad_fn=<AddBackward0>)
# tensor([0.2866], grad_fn=<AddBackward0>)
# tensor([0.2926], grad_fn=<AddBackward0>)
# tensor([0.2922], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2914], grad_fn=<AddBackward0>)
# tensor([0.2943], grad_fn=<AddBackward0>)
# tensor([0.2907], grad_fn=<AddBackward0>)
# tensor([0.2887], grad_fn=<AddBackward0>)
# tensor([0.2887], grad_fn=<AddBackward0>)
# tensor([0.2909], grad_fn=<AddBackward0>)
# tensor([0.2931], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2927], grad_fn=<AddBackward0>)
# tensor([0.2941], grad_fn=<AddBackward0>)
# tensor([0.2923], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2927], grad_fn=<AddBackward0>)
# tensor([0.2956], grad_fn=<AddBackward0>)
# tensor([0.2929], grad_fn=<AddBackward0>)
# tensor([0.2941], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2942], grad_fn=<AddBackward0>)
# tensor([0.2929], grad_fn=<AddBackward0>)
# tensor([0.2936], grad_fn=<AddBackward0>)
# tensor([0.2932], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2951], grad_fn=<AddBackward0>)
# tensor([0.2935], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2918], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.2903], grad_fn=<AddBackward0>)
# tensor([0.2902], grad_fn=<AddBackward0>)
# tensor([0.2914], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2902], grad_fn=<AddBackward0>)
# tensor([0.2891], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2895], grad_fn=<AddBackward0>)
# tensor([0.2901], grad_fn=<AddBackward0>)
# tensor([0.2909], grad_fn=<AddBackward0>)
# tensor([0.2914], grad_fn=<AddBackward0>)
# tensor([0.2952], grad_fn=<AddBackward0>)
# tensor([0.2984], grad_fn=<AddBackward0>)
# tensor([0.2890], grad_fn=<AddBackward0>)
# tensor([0.2981], grad_fn=<AddBackward0>)
# tensor([0.2952], grad_fn=<AddBackward0>)
# tensor([0.2924], grad_fn=<AddBackward0>)
# tensor([0.3036], grad_fn=<AddBackward0>)
# tensor([0.3012], grad_fn=<AddBackward0>)
# tensor([0.3002], grad_fn=<AddBackward0>)
# tensor([0.2961], grad_fn=<AddBackward0>)
# tensor([0.2944], grad_fn=<AddBackward0>)
# tensor([0.2991], grad_fn=<AddBackward0>)
# tensor([0.2950], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2970], grad_fn=<AddBackward0>)
# tensor([0.3106], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2967], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2930], grad_fn=<AddBackward0>)
# tensor([0.2940], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2897], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2757], grad_fn=<AddBackward0>)
# tensor([0.2783], grad_fn=<AddBackward0>)
# tensor([0.2808], grad_fn=<AddBackward0>)
# tensor([0.2817], grad_fn=<AddBackward0>)
# tensor([0.2815], grad_fn=<AddBackward0>)
# tensor([0.2809], grad_fn=<AddBackward0>)
# tensor([0.2819], grad_fn=<AddBackward0>)
# tensor([0.2788], grad_fn=<AddBackward0>)
# tensor([0.2832], grad_fn=<AddBackward0>)
# tensor([0.2828], grad_fn=<AddBackward0>)
# tensor([0.2825], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2851], grad_fn=<AddBackward0>)
# tensor([0.2892], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2880], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2985], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2853], grad_fn=<AddBackward0>)
# tensor([0.2834], grad_fn=<AddBackward0>)
# tensor([0.2826], grad_fn=<AddBackward0>)
# tensor([0.2830], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2875], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2841], grad_fn=<AddBackward0>)
# tensor([0.2855], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2850], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2796], grad_fn=<AddBackward0>)
# tensor([0.2801], grad_fn=<AddBackward0>)
# tensor([0.2827], grad_fn=<AddBackward0>)
# tensor([0.2791], grad_fn=<AddBackward0>)
# tensor([0.2810], grad_fn=<AddBackward0>)
# tensor([0.2837], grad_fn=<AddBackward0>)
# tensor([0.2836], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2757], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2861], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2840], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2844], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2845], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.3045], grad_fn=<AddBackward0>)
# tensor([0.2944], grad_fn=<AddBackward0>)
# tensor([0.2986], grad_fn=<AddBackward0>)
# tensor([0.2924], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2925], grad_fn=<AddBackward0>)
# tensor([0.2925], grad_fn=<AddBackward0>)
# tensor([0.2925], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.3010], grad_fn=<AddBackward0>)
# tensor([0.2919], grad_fn=<AddBackward0>)
# tensor([0.2924], grad_fn=<AddBackward0>)
# tensor([0.2877], grad_fn=<AddBackward0>)
# tensor([0.2900], grad_fn=<AddBackward0>)
# tensor([0.2914], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2886], grad_fn=<AddBackward0>)
# tensor([0.2877], grad_fn=<AddBackward0>)
# tensor([0.2873], grad_fn=<AddBackward0>)
# tensor([0.2884], grad_fn=<AddBackward0>)
# tensor([0.2858], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2914], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2913], grad_fn=<AddBackward0>)
# tensor([0.3008], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.2962], grad_fn=<AddBackward0>)
# tensor([0.3031], grad_fn=<AddBackward0>)
# tensor([0.3017], grad_fn=<AddBackward0>)
# tensor([0.2958], grad_fn=<AddBackward0>)
# tensor([0.2988], grad_fn=<AddBackward0>)
# tensor([0.2993], grad_fn=<AddBackward0>)
# tensor([0.3034], grad_fn=<AddBackward0>)
# tensor([0.2982], grad_fn=<AddBackward0>)
# tensor([0.2968], grad_fn=<AddBackward0>)
# tensor([0.3025], grad_fn=<AddBackward0>)
# tensor([0.3034], grad_fn=<AddBackward0>)
# tensor([0.2976], grad_fn=<AddBackward0>)
# tensor([0.3077], grad_fn=<AddBackward0>)
# tensor([0.3091], grad_fn=<AddBackward0>)
# tensor([0.3038], grad_fn=<AddBackward0>)
# tensor([0.3045], grad_fn=<AddBackward0>)
# tensor([0.2956], grad_fn=<AddBackward0>)
# tensor([0.2963], grad_fn=<AddBackward0>)
# tensor([0.2962], grad_fn=<AddBackward0>)
# tensor([0.2957], grad_fn=<AddBackward0>)
# tensor([0.2960], grad_fn=<AddBackward0>)
# tensor([0.2943], grad_fn=<AddBackward0>)
# tensor([0.2930], grad_fn=<AddBackward0>)
# tensor([0.2926], grad_fn=<AddBackward0>)
# tensor([0.2940], grad_fn=<AddBackward0>)
# tensor([0.2923], grad_fn=<AddBackward0>)
# tensor([0.2918], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2911], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2926], grad_fn=<AddBackward0>)
# tensor([0.2946], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2883], grad_fn=<AddBackward0>)
# tensor([0.2896], grad_fn=<AddBackward0>)
# tensor([0.2909], grad_fn=<AddBackward0>)
# tensor([0.2918], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2959], grad_fn=<AddBackward0>)
# tensor([0.2958], grad_fn=<AddBackward0>)
# tensor([0.2964], grad_fn=<AddBackward0>)
# tensor([0.2987], grad_fn=<AddBackward0>)
# tensor([0.2955], grad_fn=<AddBackward0>)
# tensor([0.2980], grad_fn=<AddBackward0>)
# tensor([0.2986], grad_fn=<AddBackward0>)
# tensor([0.2984], grad_fn=<AddBackward0>)
# tensor([0.2979], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2948], grad_fn=<AddBackward0>)
# tensor([0.2865], grad_fn=<AddBackward0>)
# tensor([0.2902], grad_fn=<AddBackward0>)
# tensor([0.2917], grad_fn=<AddBackward0>)
# tensor([0.2866], grad_fn=<AddBackward0>)
# tensor([0.2876], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2889], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2967], grad_fn=<AddBackward0>)
# tensor([0.2957], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2956], grad_fn=<AddBackward0>)
# tensor([0.2961], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2941], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2951], grad_fn=<AddBackward0>)
# tensor([0.2945], grad_fn=<AddBackward0>)
# tensor([0.2932], grad_fn=<AddBackward0>)
# tensor([0.2864], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2910], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2870], grad_fn=<AddBackward0>)
# tensor([0.2847], grad_fn=<AddBackward0>)
# tensor([0.2864], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2855], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2930], grad_fn=<AddBackward0>)
# tensor([0.2947], grad_fn=<AddBackward0>)
# tensor([0.2961], grad_fn=<AddBackward0>)
# tensor([0.2942], grad_fn=<AddBackward0>)
# tensor([0.2931], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2933], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.2885], grad_fn=<AddBackward0>)
# tensor([0.2954], grad_fn=<AddBackward0>)
# tensor([0.2937], grad_fn=<AddBackward0>)
# tensor([0.2874], grad_fn=<AddBackward0>)
# tensor([0.2857], grad_fn=<AddBackward0>)
# tensor([0.2823], grad_fn=<AddBackward0>)
# tensor([0.2929], grad_fn=<AddBackward0>)
# tensor([0.2848], grad_fn=<AddBackward0>)
# tensor([0.2860], grad_fn=<AddBackward0>)
# tensor([0.2872], grad_fn=<AddBackward0>)
# tensor([0.2862], grad_fn=<AddBackward0>)
# tensor([0.2886], grad_fn=<AddBackward0>)
# tensor([0.2896], grad_fn=<AddBackward0>)
# tensor([0.2893], grad_fn=<AddBackward0>)
# tensor([0.2893], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2871], grad_fn=<AddBackward0>)
# tensor([0.2867], grad_fn=<AddBackward0>)
# tensor([0.2856], grad_fn=<AddBackward0>)
# tensor([0.2852], grad_fn=<AddBackward0>)
# tensor([0.2859], grad_fn=<AddBackward0>)
# tensor([0.2849], grad_fn=<AddBackward0>)
# tensor([0.2961], grad_fn=<AddBackward0>)
# tensor([0.2811], grad_fn=<AddBackward0>)
# tensor([0.2811], grad_fn=<AddBackward0>)
# tensor([0.2804], grad_fn=<AddBackward0>)
# tensor([0.2803], grad_fn=<AddBackward0>)
# tensor([0.2796], grad_fn=<AddBackward0>)
# tensor([0.2787], grad_fn=<AddBackward0>)
# tensor([0.2802], grad_fn=<AddBackward0>)
# tensor([0.2938], grad_fn=<AddBackward0>)
# tensor([0.2996], grad_fn=<AddBackward0>)
# tensor([0.2998], grad_fn=<AddBackward0>)
# tensor([0.2977], grad_fn=<AddBackward0>)
# tensor([0.2980], grad_fn=<AddBackward0>)
# tensor([0.2976], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2863], grad_fn=<AddBackward0>)
# tensor([0.2842], grad_fn=<AddBackward0>)
# tensor([0.2846], grad_fn=<AddBackward0>)
# tensor([0.2898], grad_fn=<AddBackward0>)
# tensor([0.2888], grad_fn=<AddBackward0>)
# tensor([0.2864], grad_fn=<AddBackward0>)
# tensor([0.2881], grad_fn=<AddBackward0>)
# tensor([0.2916], grad_fn=<AddBackward0>)
# tensor([0.2902], grad_fn=<AddBackward0>)
# tensor([0.2899], grad_fn=<AddBackward0>)
# tensor([0.2843], grad_fn=<AddBackward0>)
# tensor([0.3058], grad_fn=<AddBackward0>)
# tensor([0.3043], grad_fn=<AddBackward0>)
# tensor([0.3038], grad_fn=<AddBackward0>)
# tensor([0.3043], grad_fn=<AddBackward0>)
# tensor([0.3049], grad_fn=<AddBackward0>)
# tensor([0.3009], grad_fn=<AddBackward0>)
# tensor([0.3012], grad_fn=<AddBackward0>)
# tensor([0.3036], grad_fn=<AddBackward0>)
# tensor([0.3026], grad_fn=<AddBackward0>)
# tensor([0.3020], grad_fn=<AddBackward0>)
# tensor([0.2986], grad_fn=<AddBackward0>)
# tensor([0.2996], grad_fn=<AddBackward0>)
# tensor([0.2978], grad_fn=<AddBackward0>)
# tensor([0.2925], grad_fn=<AddBackward0>)
# tensor([0.2944], grad_fn=<AddBackward0>)
# tensor([0.2920], grad_fn=<AddBackward0>)
# tensor([0.2891], grad_fn=<AddBackward0>)
# tensor([0.2894], grad_fn=<AddBackward0>)
# tensor([0.2928], grad_fn=<AddBackward0>)
# tensor([0.2921], grad_fn=<AddBackward0>)
# tensor([0.2886], grad_fn=<AddBackward0>)
# tensor([0.2879], grad_fn=<AddBackward0>)
# tensor([0.2930], grad_fn=<AddBackward0>)
# tensor([0.2924], grad_fn=<AddBackward0>)
# tensor([0.2812], grad_fn=<AddBackward0>)

# %%
#pip3 install coremltools==5.0b5 protobuf==3.20.1

# %%
## This code will print out the real, then expected for every batch of 32 
# for batch in loader:
#     batchX = batch[0]
#     batchY = batch[1]
#     print(batchY)
#     print(net(batchX))

# %% [markdown]
# ### Quantize and convert to TorchScript
# The process of tracing takes an example input and traces its flow through the model. You can trace the model by creating an example image input, as shown in the above code using random data. To understand the reasons for tracing and how to trace a PyTorch model, see Model Tracing.
#
#
# If your model uses a data-dependent control flow, such as a loop or conditional, the traced model won't generalize to other inputs. In such cases you can experiment with applying PyTorch's JIT script (torch.jit.script) to your model as described in Model Scripting. You can also use a combination of tracing and scripting.

# %%
model_dynamic_quantized = torch.quantization.quantize_dynamic(
    net, qconfig_spec={torch.nn.Linear}, dtype=torch.qint8
)
# set model to evaluation mode
model_dynamic_quantized.eval()
example_tensor = weather_tensor[0,:-2]
# convert to torch script
traced_script_module = torch.jit.trace(net, example_tensor)

# %%
out = traced_script_module(example_tensor)
out
# Out:
# tensor([0.2868], grad_fn=<AddBackward0>)

# %% [markdown]
# ### Convert to CoreML

# %%
import coremltools as ct

# Using image_input in the inputs parameter:
# Convert to Core ML program using the Unified Conversion API.
model = ct.convert(
    traced_script_module,
    convert_to="mlprogram",
    inputs=[ct.TensorType(shape=example_tensor.shape)]
 )
# Out:
# Model is not in eval mode. Consider calling '.eval()' on your model prior to conversion
# Converting PyTorch Frontend ==> MIL Ops:  92%|▉| 12/13 [00:00<00:00, 2968.72 ops/
# Running MIL Common passes:   0%|                     | 0/40 [00:00<?, ? passes/s]/Users/lena/opt/anaconda3/envs/sunproject/lib/python3.9/site-packages/coremltools/converters/mil/mil/passes/name_sanitization_utils.py:107: UserWarning: Input, 'input.1', of the source model, has been renamed to 'input_1' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# /Users/lena/opt/anaconda3/envs/sunproject/lib/python3.9/site-packages/coremltools/converters/mil/mil/passes/name_sanitization_utils.py:135: UserWarning: Output, '26', of the source model, has been renamed to 'var_26' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# Running MIL Common passes: 100%|██████████| 40/40 [00:00<00:00, 3193.59 passes/s]
# Running MIL FP16ComputePrecision pass: 100%|█| 1/1 [00:00<00:00, 137.02 passes/s]
# Running MIL Clean up passes: 100%|████████| 11/11 [00:00<00:00, 1150.24 passes/s]

# %% [markdown]
# got this message:
#
# Model is not in eval mode. Consider calling '.eval()' on your model prior to conversion

# %% [markdown]
# ALSO:
# As an alternative, you can convert the model to a neural network by eliminating the convert_to parameter:

# %%
# Save the converted model.
model.save("sunrise_model1.mlpackage")

# %% [markdown]
# ### success! (maybe?)
# next step is to try integrating it into my app:
# https://developer.apple.com/documentation/coreml/integrating_a_core_ml_model_into_your_app

# %% [markdown]
# ### Optimize for pytorch model

# %%
# from torch.utils.mobile_optimizer import optimize_for_mobile
# # optimize for mobile so that we can export and use in Swift app
# torchscript_model_optimized = optimize_for_mobile(traced_script_module)

# # save as .pt 
# path = os.path.join(os.getcwd(),"model.pt")
# torchscript_model_optimized._save_for_lite_interpreter(path)

# %% [markdown]
# ### Test

# %%
row = 36
test = weather_tensor[row,:]
label = labels[row]
label
# Out:
# tensor([1.])

# %%
net(test)
# Out:
# tensor([0.8277], grad_fn=<AddBackward0>)

# %% [markdown]
# NOTES FROM CORY: HOW TO SPLIT UP training, validation, testing
#
# def train(loader):
#     one tound of training with all data in the loader
#
#
# def eval(loader):
#     feed evyerhting in batches to model, adds up and takes the losses of the batches

# %%
# # create a batch norm layer
# bn = torch.nn.BatchNorm1d(num_features = xdims)
# # normalize 
# data = bn(data) # how to extract the std and mean
